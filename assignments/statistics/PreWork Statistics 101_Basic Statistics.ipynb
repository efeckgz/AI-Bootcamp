# %% [markdown]
# # theDevMasters, PreWork<br> Statistics 101: Basic Statistics

# %% [markdown]
# Company Name : theDevMasters <br>
# Author : Cloris Li <br>
# Reviewed: Zia Khan <br>
# MDS-DL Document Version : 1.0 <br>
#
# Description : PreWork, Statistics 101, Basic Statistics <br>

# %% [markdown]
# # <font color="blue">Table of Contents</font>
#
# ## Why We Need to Learn Statistics for Data Science
# 1. What is Statistics
# 2. Population Parameters vs Sample Statistics
#
# ## Variables
# 1. What is a Variable?
# 2. Types of Variables
#     * Quantitative / Numerical Variable
#     * Qualitative / Categorical Variable
#
# ## Measures of Location
# 1. Mean
# 2. Median
# 3. Mode
#
# ## Measures of Variability
# 1. Variance, Standard Deviation
# 2. Range
# 3. Percentiles, Inter-quantile Range
#
# ## Relationship between Variables
# 1. Correlation Coefficients
#     * Pearson r correlation
#     * Spearman rank correlation
# 2. Graphical Summary

# %% [markdown]
# # <font color="red">I. Why We Need to Learn Statistics for Data Science </font>

# %% [markdown]
# ## 1.1 What is Statistics
# Statistics is a broad field with applications in many industries. Wikipedia defines it as _**the study of the collection, analysis, interpretation, presentation, and organization of data**_. Statistics is both the science of uncertainty and the technology of extracting information from data.
#
# Therefore, it shouldn’t be a surprise that data scientists need to know statistics.<br>
#
# Statistics can be a powerful tool when performing the art of Data Science (DS). From a high-level view, statistics is the use of mathematics to perform technical analysis of data. A basic visualisation such as a bar chart might give you some high-level information, but with statistics we get to operate on the data in a much more information-driven and targeted way. The math involved helps us form concrete conclusions about our data rather than just guesstimating.<br>
#
# For example, data analysis requires descriptive statistics and probability theory, at a minimum. These concepts will help you make better business decisions from data. <br>
#
# Using statistics, we can gain deeper and more fine grained insights into how exactly our data is structured and based on that structure how we can optimally apply other data science techniques to get even more information.

# %% [markdown]
# ## 1.2 Population Parameters vs Sample Statistics
# A **parameter** is a value that describes a characteristic of an entire population, such as the population mean. Because you can almost never measure an entire population, you usually don’t know the real value of a parameter. In fact, parameter values are nearly always unknowable. While we don’t know the value, it definitely exists.<br>
#
# The population mean and standard deviation are two common parameters. In statistics, Greek symbols usually represent population parameters, such as μ (mu) for the mean and σ (sigma) for the standard deviation.<br>
#
# A **statistic** is a characteristic of a sample. If you collect a sample and calculate the mean and standard deviation, these are sample statistics. Inferential statistics allow you to use sample statistics to make conclusions about a population. However, to draw valid conclusions, you must use particular sampling techniques. These techniques help ensure that samples produce unbiased estimates.<br>
#
# In inferential statistics, we use **sample statistics** to estimate **population parameters**. For example, if we collect a random sample of adult women in the United States and measure their heights, we can calculate the sample mean and use it as an unbiased estimate of the population mean. We can also perform hypothesis testing on the sample estimate and create confidence intervals to construct a range that the actual population value likely falls within.

# %% [markdown]
# <font color="green">**Q : Can you think of another example of population parameter and sample statistics?**</font>

# %% [markdown]
# A: Average social media usage of everybody in the world. To accurately calculate this we would need to know the average social media usage of each individual in the world, which is very difficult. We could collect a random sample of people from the world and get their average social media usage, which would give us a sample mean, from which we can infer a population mean.

# %% [markdown]
# # <font color="red">II. Variables</font>

# %% [markdown]
# ## 2.1 What is a Variable?
#
# A **variable** is a characteristic of an object. A variable may also be called a data item. <br>
#
# Age, gender, business income and expenses, country of birth, capital expenditure, class grades, eye colour and vehicle type are examples of variables. It is called a variable because the value may vary between data units in a population, and may change in value over time.

# %% [markdown]
# ## 2.2 Types of Variables
#
# There are different ways variables can be described according to the ways they can be studied, measured, and presented.<br>
#
# Here we consider two main types of variables: Qualitative variable or Quantitative variable

# %% [markdown]
# ### 2.2.1 Quantitative / Numerical Variable
# Numeric variables have values that describe a measurable quantity as a number, like 'how many' or 'how much'. Therefore numeric variables are quantitative variables.<br>
#
# Numeric variables may be further described as either **continuous** or **discrete**:<br>
#
# * A **continuous** variable is a numeric variable. Observations can take any value between a certain set of real numbers. The value given to an observation for a continuous variable can include values as small as the instrument of measurement allows. Examples of continuous variables include height, time, age, and temperature.
# * A **discrete** variable is a numeric variable. Observations can take a value based on a count from a set of distinct whole values. A discrete variable cannot take the value of a fraction between one value and the next closest value. Examples of discrete variables include the number of registered cars, number of business locations, and number of children in a family, all of of which measured as whole units (i.e. 1, 2, 3 cars).<br>
#
# The data collected for a numeric variable are quantitative data.

# %% [markdown]
# <font color="green">**Q : Can you think of another example of a continuous variable and a discrete variable?**</font>

# %% [markdown]
# A: Continuous: The distance between two places, Discreate: Total goals scored in a game of football.

# %% [markdown]
# ### 2.2.2 Qualitative / Categorical Variable
# Categorical variables have values that describe a 'quality' or 'characteristic' of a data unit, like 'what type' or 'which category'. Categorical variables fall into mutually exclusive (in one category or in another) and exhaustive (include all possible options) categories. Therefore, categorical variables are qualitative variables and tend to be represented by a non-numeric value.<br>
#
# Categorical variables may be further described as **ordinal** or **nominal**:<br>
#
# * An **ordinal** variable is a categorical variable. Observations can take a value that can be logically ordered or ranked. The categories associated with ordinal variables can be ranked higher or lower than another, but do not necessarily establish a numeric difference between each category. Examples of ordinal categorical variables include academic grades (i.e. A, B, C), clothing size (i.e. small, medium, large, extra large) and attitudes (i.e. strongly agree, agree, disagree, strongly disagree).
# * A **nominal** variable is a categorical variable. Observations can take a value that is not able to be organised in a logical sequence. Examples of nominal categorical variables include sex, business type, eye colour, religion and brand.<br>
#
# The data collected for a categorical variable are qualitative data.

# %% [markdown]
# <font color="green">**Q : Can you think of another example of a ordinal variable and a nominal variable?**</font>

# %% [markdown]
# A: Ordinal: The specification of a consumer product (eg: iPhone mini, iPhone Pro, iPhone Pro Max), Nominal: The color of a car

# %% [markdown]
# # <font color="red">III. Measures of Location</font>

# %% [markdown]
# The farthest one can reduce a set of data, and still retain any information at all, is to summarize the data with a single value. Measures of location do just that: They try to capture with a single number what is typical of the data.<br>
#
# What single number is most representative of an entire list of numbers? We will study three common measures of location: the **mean**, the **median**, and the **mode**. The mean, median and mode are all "most representative," but for different, related notions of representativeness.

# %% [markdown]
# ## 3.1 Mean
# The mean (more precisely, the arithmetic mean) is commonly called the average. It is the sum of the data, divided by the number of data.

# %%
def expectation(array):
    addmeup = sum(array)
    expected = addmeup / len(array)
    print("The expected number of", array, " is ", expected)

# %% [markdown]
# **Bonus**: Write your own function that will calculate the mean.

# %%
def find_avg(arr):
    sum = 0
    for i in range(len(arr)):
        sum += arr[i]

    return sum / len(arr)

# %%
speedlimits = [60,55,65,30,45,50,55,45]
expectation(speedlimits)
print(f"My function finds the average as {find_avg(speedlimits)}.")
# Out:
# The expected number of [60, 55, 65, 30, 45, 50, 55, 45]  is  50.625
# My function finds the average as 50.625.

# %% [markdown]
# But when the programming becomes secondhand, we will use packages to reduce the lines of code.

# %%
import numpy as np
np.mean(speedlimits)
# Out:
# 50.625

# %% [markdown]
# **Bonus**: Why do you think we use the average (the mean) to describe this population? <br>
# In what scenario should you reconsider using the average?

# %% [markdown]
# A: If there are many outliers in the data

# %% [markdown]
# ## 3.2 Median
# The median is the number that divides the (ordered) data in half—the smallest number that is at least as big as half the data. At least half the data are equal to or smaller than the median, and at least half the data are equal to or greater than the median.

# %% [markdown]
# Python has a sort function, but the middle differs between odd number of variables vs even number of variables, median is the least favorite to program, but here we are:

# %%
def median_calc(lst):
    lst = sorted(lst) # sort the array
    if len(lst) < 1: 
            return None # If the length of the array is 0, there is no median value.
    if len(lst) %2 == 1: 
            return lst[int((len(lst)+1)/2-1)] # If the array is odd sized, the median is the item that is right at the middle.
    else: 
            return (lst[int(len(lst)/2)-1]+lst[int(len(lst)/2)])/2.0 # If the array is even sized, the median is the average of the two items at the middle of the array.

# %% [markdown]
# **Bonus** : Comment on each line of the median function above on what the line does.

# %%
median_calc(speedlimits)
# Out:
# 52.5

# %% [markdown]
# Now let's try calculating median using imported functions:

# %%
# NumPy:
from numpy import median
median(speedlimits)
# Out:
# 52.5

# %%
# statistics:
from statistics import median
median(speedlimits)
# Out:
# 52.5

# %% [markdown]
# **Bonus**: Why do you think we use the median to describe this population? <br>
# In what scenario should you reconsider using the median?

# %% [markdown]
# A: If the data has many outliers, the median would give a more consistent result.

# %% [markdown]
# ## 3.3 Mode
# The mode of a set of data (as opposed to the mode of a histogram) is the most common value among the data. It is rare that several data coincide exactly, unless the variable is discrete, or the measurements are reported with low precision.<br>
#
# For qualitative and categorical data, the mode makes sense, but the mean and median do not.

# %%
from scipy.stats import mode
mode(speedlimits)
# Out:
# ModeResult(mode=45, count=2)

# %% [markdown]
# **Bonus**: For the ambitious, write a function that will calculate the mode.

# %%
# A function to return the unique items of an array.
def find_uniques(arr):
    uniques = []
    for i in range(len(arr)):
        if arr[i] not in uniques:
            uniques.append(arr[i])
    return uniques

# This function gets the unique values of the array from the find_uniques function and counts their apperance.
# It saves the results into a counts array in the appropriate index. The item at uniques[i] appears counts[i]
# times in arr. It then returns the value of uniques at the index of the maximun value of counts.
# Note that this function asssumes the input array has only one mode. If the array has more than one modes, like the
# speedlimits array above, the function will return one of the modes.
def find_mode(arr):
    uniques = find_uniques(arr)
    counts = []
    for unique in uniques:
        this_count = 0
        for val in arr:
            if val == unique:
                this_count += 1
        counts.append(this_count)
    return uniques[counts.index(max(counts))]

# lets test this
test = [1, 1, 1, 1, 2, 3, 4, 4, 4, 5, 6, 6, 6, 6, 6, 6, 6, 7, 8, 8, 8, 9] # The mode is 6 here.
assert find_mode(test) == 6
print("yay!")
# Out:
# yay!

# %% [markdown]
# # <font color="red">IV. Measures of Variability</font>

# %% [markdown]
# Variability refers to how "spread out" a group of values is.<br>
#
# There are four frequently used measures of variability: the range, interquartile range, variance, and standard deviation.

# %% [markdown]
# ## 4.1 Variance and Standard Deviation
# Variability can be defined in terms of how close the values in the distribution are to the middle of the distribution. Using the mean as the measure of the middle of the distribution, the **variance** is defined as the average squared difference of the values from the mean.<br>
#
# The **standard deviation** is simply the square root of the variance. The standard deviation is an especially useful measure of variability when the distribution is normal or approximately normal because the proportion of the distribution within a given number of standard deviations from the mean can be calculated.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In Python, NumPy has functions for calculating variance and standard deviation.

# %%
import numpy as np
np.var(speedlimits), np.std(speedlimits)
# Out:
# (102.734375, 10.135796712641785)

# %%
import math
math.sqrt(np.var(speedlimits))
# Out:
# 10.135796712641785

# %% [markdown]
# Or calculate manually:

# %%
# calculate mean
mu = sum(speedlimits) / len(speedlimits)

# calculate variance using a list comprehension
var_calc = sum((xi - mu) ** 2 for xi in speedlimits) / len(speedlimits)
var_calc
# Out:
# 102.734375

# %% [markdown]
# ## 4.2 Range
# The **range** of a list is the largest value minus the smallest value. It is the width of the smallest interval that contains all the data, so it measures spread.
#
# The range is the simplest measure of variability to calculate, and one you have probably encountered many times in your life. Let’s take an example: What is the range of the following group of numbers: 10, 2, 5, 6, 7, 3, 4? Well, the highest number is 10, and the lowest number is 2, so 10 - 2 = 8. The range is 8.

# %%
range = max(speedlimits) - min(speedlimits)
print("The range of the speed limits is: ", range)
# Out:
# The range of the speed limits is:  35

# %% [markdown]
# ## 4.3 Percentiles and Inter-quantile Range (IQR)
# **Percentiles** are used to understand and interpret data. They indicate the values below which a certain percentage of the data in a data set is found.<br>
#
# Percentiles can be calculated using the formula n = (P/100) x N, where P = percentile, N = number of values in a data set (sorted from smallest to largest), and n = ordinal rank of a given value.
#
# The **Interquantile Range (IQR)** is the upper quartile (75th percentile), minus the lower quartile (25th percentile). It is the width of the interval that contains the middle 50% of the data—and thus is a measure of spread. It is insensitive to the most extreme values of the data (assuming that there are more than four data).

# %%
# Calculate percentiles and IQR using NumPy
p_median = np.percentile(speedlimits, 50) # return 50th percentile, e.g median.
p_first = np.percentile(speedlimits, 25) # return 25th percentile
p_third = np.percentile(speedlimits, 75) # return 75th percentile
IQR = p_third - p_first
print("The median of the speed limits is: ", p_median)
print("The Interquantile Range of the speed limits is: ", IQR)
# Out:
# The median of the speed limits is:  52.5
# The Interquantile Range of the speed limits is:  11.25

# %% [markdown]
# # <font color="red">V. Relationship between Variables</font>

# %% [markdown]
# ## 5.1 Correlation Coefficients
# Correlation is a bivariate analysis that measures the strength of association between two variables and the direction of the relationship.<br>
#
# In terms of the strength of relationship, the value of the correlation coefficient varies between +1 and -1.  A value of ± 1 indicates a perfect degree of association between the two variables.  As the correlation coefficient value goes towards 0, the relationship between the two variables will be weaker.<br>
#
# The direction of the relationship is indicated by the sign of the coefficient; a + sign indicates a positive relationship and a – sign indicates a negative relationship.

# %% [markdown]
# ### 5.1.1 Pearson r correlation
# **Pearson r correlation** is the most widely used correlation statistic to measure the degree of the relationship between variables. It evaluates the linear relationship between two continuous variables. A relationship is linear when a change in one variable is associated with a proportional change in the other variable.<br>
#
# For example, in the stock market, if we want to measure how two stocks are related to each other, Pearson r correlation is used to measure the degree of relationship between the two. <br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Assumptions:**
# * Both variables should be normally distributed (normally distributed variables have a bell-shaped curve).
# * Linearity and homoscedasticity.  Linearity assumes a straight line relationship between each of the two variables and homoscedasticity assumes that data is equally distributed about the regression line.

# %% [markdown]
# Let's learn how we can calculate Pearson r correlation in Python:

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

# Positive Correlation with some noise
y = x + np.random.normal(0, 10, 1000)

# %%
from scipy import stats
stats.pearsonr(x, y)
# Out:
# PearsonRResult(statistic=0.8021735035633775, pvalue=9.687377592535968e-226)

# %% [markdown]
# ### 5.1.2 Spearman rank correlation
# Spearman rank correlation is a non-parametric test that is used to measure the degree of association between two variables.  The Spearman rank correlation test does not carry any assumptions about the distribution of the data and is the appropriate correlation analysis when the variables are measured on a scale that is at least ordinal.<br>
#
# The Spearman correlation evaluates the monotonic relationship between two continuous or ordinal variables. In a monotonic relationship, the variables tend to change together, but not necessarily at a constant rate. The Spearman correlation coefficient is based on the ranked values for each variable rather than the raw data.<br>
#
# Spearman correlation is often used to evaluate relationships involving ordinal variables. For example, you might use a Spearman correlation to evaluate whether the order in which employees complete a test exercise is related to the number of months they have been employed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Assumptions:**
# * Data must be at least ordinal
# * The values on one variable must be monotonically related to the other variable.

# %% [markdown]
# Let's see how we can calculate Spearman rank correlation in Python:

# %%
from scipy import stats
stats.spearmanr(x, y)
# Out:
# SignificanceResult(statistic=0.8090999673852567, pvalue=1.230412209861859e-232)

# %% [markdown]
# ## 5.2 Graphical Summary
# We can draw scatter plot to observe the relationship between variables.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(x, y)
plt.show()

# %% [markdown]
# From the scatter plot, we can see a positive linear relationship between x and y.
