# %% [markdown]
# # Predicting House prices using advanced regression
#
# ## Introduction
#
# In this notebook we will use advanced regression techniques to predict house prices from a given data set.
#
# ### Data fields
#
# 1. SalePrice: The property's sale price in dollars. This is the target variable that you're
# trying to predict.
# 2. MSSubClass: The building class
# 3. MSZoning: The general zoning classification
# 4. LotFrontage: Linear feet of street connected to property
# 5. LotArea: Lot size in square feet
# 6. Street: Type of road access
# 7. Alley: Type of alley access
# 8. LotShape: General shape of property
# 9. LandContour: Flatness of the property
# 10. Utilities: Type of utilities available
# 11. LotConfig: Lot configuration
# 12. LandSlope: Slope of property
# 13. Neighborhood: Physical locations within Ames city limits
# 14. Condition1: Proximity to main road or railroad
# 15. Condition2: Proximity to main road or railroad (if a second is present)
# 16. BldgType: Type of dwelling
# 17. HouseStyle: Style of dwelling
# 18. OverallQual: Overall material and finish quality
# 19. OverallCond: Overall condition rating
# 20. YearBuilt: Original construction date
# 21. YearRemodAdd: Remodel date
# 22. RoofStyle: Type of roof
# 23. RoofMatl: Roof material
# 24. Exterior1st: Exterior covering on house
# 25. Exterior2nd: Exterior covering on house (if more than one material)
# 26. MasVnrType: Masonry veneer type
# 27. MasVnrArea: Masonry veneer area in square feet
# 28. ExterQual: Exterior material quality
# 29. ExterCond: Present condition of the material on the exterior
# 30. Foundation: Type of foundation
# 31. BsmtQual: Height of the basement
# 32. BsmtCond: General condition of the basement
# 33. BsmtExposure: Walkout or garden level basement walls
# 34. BsmtFinType1: Quality of basement finished area
# 35. BsmtFinSF1: Type 1 finished square feet
# 36. BsmtFinType2: Quality of second finished area (if present)
# 37. BsmtFinSF2: Type 2 finished square feet
# 38. BsmtUnfSF: Unfinished square feet of basement area
# 39. TotalBsmtSF: Total square feet of basement area
# 40. Heating: Type of heating
# 41. HeatingQC: Heating quality and condition
# 42. CentralAir: Central air conditioning
# 43. Electrical: Electrical system
# 44. 1stFlrSF: First Floor square feet
# 45. 2ndFlrSF: Second floor square feet
# 46. LowQualFinSF: Low quality finished square feet (all floors)
# 47. GrLivArea: Above grade (ground) living area square feet
# 48. BsmtFullBath: Basement full bathrooms
# 49. BsmtHalfBath: Basement half bathrooms
# 50. FullBath: Full bathrooms above grade
# 51. HalfBath: Half baths above grade
# 52. Bedroom: Number of bedrooms above basement level
# 53. Kitchen: Number of kitchens
# 54. KitchenQual: Kitchen quality
# 55. TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# 56. Functional: Home functionality rating
# 57. Fireplaces: Number of fireplaces
# 58. FireplaceQu: Fireplace quality
# 59. GarageType: Garage location
# 60. GarageYrBlt: Year garage was built
# 61. GarageFinish: Interior finish of the garage
# 62. GarageCars: Size of garage in car capacity
# 63. GarageArea: Size of garage in square feet
# 64. GarageQual: Garage quality
# 65. GarageCond: Garage condition
# 66. PavedDrive: Paved driveway
# 67. WoodDeckSF: Wood deck area in square feet
# 68. OpenPorchSF: Open porch area in square feet
# 69. EnclosedPorch: Enclosed porch area in square feet
# 70. 3SsnPorch: Three season porch area in square feet
# 71. ScreenPorch: Screen porch area in square feet
# 72. PoolArea: Pool area in square feet
# 73. PoolQC: Pool quality
# 74. Fence: Fence quality
# 75. MiscFeature: Miscellaneous feature not covered in other categories
# 76. MiscVal: $Value of miscellaneous feature
# 77. MoSold: Month Sold
# 78. YrSold: Year Sold
# 79. SaleType: Type of sale
# 80. SaleCondition: Condition of sale

# %% [markdown]
# ## Prepare the data

# %% [markdown]
# ### import the files

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
tr = pd.read_csv('train.csv')
tt = pd.read_csv('test.csv')
test_ids = tt['Id'] # save the id column of the test data for use later.
# Out:
# 0    1461
# 1    1462
# 2    1463
# 3    1464
# 4    1465
# Name: Id, dtype: int64

# %% [markdown]
# ### Merge the files

# %%
df = pd.concat([tr, tt])
trsize = len(tr) # This is the index after which null values appear in the SalePrice column. Use this for EDA.
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ       706.0          Unf         0.0      150.0        856.0
# 1          ALQ       978.0          Unf         0.0      284.0       1262.0
# 2          GLQ       486.0          Unf         0.0      434.0        920.0
# 3          ALQ       216.0          Unf         0.0      540.0        756.0
# 4          GLQ       655.0          Unf         0.0      490.0       1145.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710           1.0           0.0         2         1             3
# 1       1262           0.0           1.0         2         0             3
# 2       1786           1.0           0.0         2         1             3
# 3       1717           1.0           0.0         1         0             3
# 4       2198           1.0           0.0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn         2.0       548.0         TA
# 1     Attchd       1976.0          RFn         2.0       460.0         TA
# 2     Attchd       2001.0          RFn         2.0       608.0         TA
# 3     Detchd       1998.0          Unf         3.0       642.0         TA
# 4     Attchd       2000.0          RFn         3.0       836.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal   208500.0
# 1       WD        Normal   181500.0
# 2       WD        Normal   223500.0
# 3       WD       Abnorml   140000.0
# 4       WD        Normal   250000.0

# %% [markdown]
# ## Analyze the data
#
# The data analysis part was inspired by [This guide](https://www.kaggle.com/code/gusthema/house-prices-prediction-using-tfdf/notebook#House-Prices-Prediction-using-TensorFlow-Decision-Forests).

# %% [markdown]
# ### EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings

filterwarnings('ignore')

# %%
def percent_col(df, col):
    return (df[col].isnull().sum() / len(df)) * 100

# %%
def barplot_nulls(df, figsize=(15, 6), percentage=False, palette='bright'):
    """
        A function that draws a barplot that shows the count or the percentages of the empty values
        in a data frame. It does not show columns with no null values in the graph.
    """
    
    nulls = df.isnull().sum()
    title = f'Null value {"percentages" if percentage else "counts"} of columns with nonzero null values.'
    
    if percentage:
        nulls = (nulls / len(df)) * 100
        
    
    nulls = nulls[nulls > 0] # Filter the zeros.
    
    nulls_df = nulls.reset_index()
    nulls_df.columns = ['Column', 'Missing Values']
    
    plt.figure(figsize=figsize)
    plt.title(title)
    sns.barplot(y=nulls_df['Missing Values'], x=nulls_df['Column'], palette=palette);

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# No duplicated rows.

# %%
df.shape
# Out:
# (2919, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ       706.0          Unf         0.0      150.0        856.0
# 1          ALQ       978.0          Unf         0.0      284.0       1262.0
# 2          GLQ       486.0          Unf         0.0      434.0        920.0
# 3          ALQ       216.0          Unf         0.0      540.0        756.0
# 4          GLQ       655.0          Unf         0.0      490.0       1145.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710           1.0           0.0         2         1             3
# 1       1262           0.0           1.0         2         0             3
# 2       1786           1.0           0.0         2         1             3
# 3       1717           1.0           0.0         1         0             3
# 4       2198           1.0           0.0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn         2.0       548.0         TA
# 1     Attchd       1976.0          RFn         2.0       460.0         TA
# 2     Attchd       2001.0          RFn         2.0       608.0         TA
# 3     Detchd       1998.0          Unf         3.0       642.0         TA
# 4     Attchd       2000.0          RFn         3.0       836.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal   208500.0
# 1       WD        Normal   181500.0
# 2       WD        Normal   223500.0
# 3       WD       Abnorml   140000.0
# 4       WD        Normal   250000.0

# %% [markdown]
# Save and drop the id column becuase it is not necessary.

# %%
# idcol = df['Id']
df.drop('Id', axis=1, inplace=True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ       706.0          Unf         0.0      150.0        856.0
# 1          ALQ       978.0          Unf         0.0      284.0       1262.0
# 2          GLQ       486.0          Unf         0.0      434.0        920.0
# 3          ALQ       216.0          Unf         0.0      540.0        756.0
# 4          GLQ       655.0          Unf         0.0      490.0       1145.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710           1.0           0.0         2         1             3
# 1       1262           0.0           1.0         2         0             3
# 2       1786           1.0           0.0         2         1             3
# 3       1717           1.0           0.0         1         0             3
# 4       2198           1.0           0.0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn         2.0       548.0         TA
# 1     Attchd       1976.0          RFn         2.0       460.0         TA
# 2     Attchd       2001.0          RFn         2.0       608.0         TA
# 3     Detchd       1998.0          Unf         3.0       642.0         TA
# 4     Attchd       2000.0          RFn         3.0       836.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal   208500.0
# 1       WD        Normal   181500.0
# 2       WD        Normal   223500.0
# 3       WD       Abnorml   140000.0
# 4       WD        Normal   250000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2919 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2915 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
#  17  OverallCond    2919 non-null   int64
#  18  YearBuilt      2919 non-null   int64
#  19  YearRemodAdd   2919 non-null   int64
#  20  RoofStyle      2919 non-null   object
#  21  RoofMatl       2919 non-null   object
#  22  Exterior1st    2918 non-null   object
#  23  Exterior2nd    2918 non-null   object
#  24  MasVnrType     1153 non-null   object
#  25  MasVnrArea     2896 non-null   float64
#  26  ExterQual      2919 non-null   object
#  27  ExterCond      2919 non-null   object
#  28  Foundation     2919 non-null   object
#  29  BsmtQual       2838 non-null   object
#  30  BsmtCond       2837 non-null   object
#  31  BsmtExposure   2837 non-null   object
#  32  BsmtFinType1   2840 non-null   object
#  33  BsmtFinSF1     2918 non-null   float64
#  34  BsmtFinType2   2839 non-null   object
#  35  BsmtFinSF2     2918 non-null   float64
#  36  BsmtUnfSF      2918 non-null   float64
#  37  TotalBsmtSF    2918 non-null   float64
#  38  Heating        2919 non-null   object
#  39  HeatingQC      2919 non-null   object
#  40  CentralAir     2919 non-null   object
#  41  Electrical     2918 non-null   object
#  42  1stFlrSF       2919 non-null   int64
#  43  2ndFlrSF       2919 non-null   int64
#  44  LowQualFinSF   2919 non-null   int64
#  45  GrLivArea      2919 non-null   int64
#  46  BsmtFullBath   2917 non-null   float64
#  47  BsmtHalfBath   2917 non-null   float64
#  48  FullBath       2919 non-null   int64
#  49  HalfBath       2919 non-null   int64
#  50  BedroomAbvGr   2919 non-null   int64
#  51  KitchenAbvGr   2919 non-null   int64
#  52  KitchenQual    2918 non-null   object
#  53  TotRmsAbvGrd   2919 non-null   int64
#  54  Functional     2917 non-null   object
#  55  Fireplaces     2919 non-null   int64
#  56  FireplaceQu    1499 non-null   object
#  57  GarageType     2762 non-null   object
#  58  GarageYrBlt    2760 non-null   float64
#  59  GarageFinish   2760 non-null   object
#  60  GarageCars     2918 non-null   float64
#  61  GarageArea     2918 non-null   float64
#  62  GarageQual     2760 non-null   object
#  63  GarageCond     2760 non-null   object
#  64  PavedDrive     2919 non-null   object
#  65  WoodDeckSF     2919 non-null   int64
#  66  OpenPorchSF    2919 non-null   int64
#  67  EnclosedPorch  2919 non-null   int64
#  68  3SsnPorch      2919 non-null   int64
#  69  ScreenPorch    2919 non-null   int64
#  70  PoolArea       2919 non-null   int64
#  71  PoolQC         10 non-null     object
#  72  Fence          571 non-null    object
#  73  MiscFeature    105 non-null    object
#  74  MiscVal        2919 non-null   int64
#  75  MoSold         2919 non-null   int64
#  76  YrSold         2919 non-null   int64
#  77  SaleType       2918 non-null   object
#  78  SaleCondition  2919 non-null   object
#  79  SalePrice      1460 non-null   float64
# dtypes: float64(12), int64(25), object(43)
# memory usage: 1.8+ MB

# %%
df[:trsize].SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(15, 6))
sns.distplot(df[:trsize].SalePrice, color='g', bins=100, hist_kws={'alpha': 0.4});
plt.title('Distribution of sale price');

# %%
list(set(df.dtypes.tolist()))
# Out:
# [dtype('int64'), dtype('float64'), dtype('O')]

# %%
df_numeric = df.select_dtypes(['int64', 'float64'])
df_numeric.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0       706.0         0.0      150.0        856.0
# 1          1976         0.0       978.0         0.0      284.0       1262.0
# 2          2002       162.0       486.0         0.0      434.0        920.0
# 3          1970         0.0       216.0         0.0      540.0        756.0
# 4          2000       350.0       655.0         0.0      490.0       1145.0
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       856       854             0       1710           1.0           0.0
# 1      1262         0             0       1262           0.0           1.0
# 2       920       866             0       1786           1.0           0.0
# 3       961       756             0       1717           1.0           0.0
# 4      1145      1053             0       2198           1.0           0.0
#
#    FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  \
# 0         2         1             3             1             8           0
# 1         2         0             3             1             6           1
# 2         2         1             3             1             6           1
# 3         1         0             3             1             7           1
# 4         2         1             4             1             9           1
#
#    GarageYrBlt  GarageCars  GarageArea  WoodDeckSF  OpenPorchSF  \
# 0       2003.0         2.0       548.0           0           61
# 1       1976.0         2.0       460.0         298            0
# 2       2001.0         2.0       608.0           0           42
# 3       1998.0         3.0       642.0           0           35
# 4       2000.0         3.0       836.0         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# 0              0          0            0         0        0       2    2008
# 1              0          0            0         0        0       5    2007
# 2              0          0            0         0        0       9    2008
# 3            272          0            0         0        0       2    2006
# 4              0          0            0         0        0      12    2008
#
#    SalePrice
# 0   208500.0
# 1   181500.0
# 2   223500.0
# 3   140000.0
# 4   250000.0

# %% [markdown]
# The distributions of all the numeric values

# %%
df_numeric.hist(figsize=(16, 20), bins=100, xlabelsize=8, ylabelsize=8);

# %%
corr = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(35, 20))
sns.heatmap(corr, annot=True);

# %% [markdown]
# ### Getting the data ready

# %% [markdown]
# #### Handling null values

# %%
# percentage of the null values for columns that have more than 0 null values.

df.isnull().sum()[df.isnull().sum() > 0] * 100 / len(df)
# Out:
# MSZoning         0.137033
# LotFrontage     16.649538
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType      60.500171
# MasVnrArea       0.787941
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinSF1       0.034258
# BsmtFinType2     2.740665
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# Electrical       0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# SalePrice       49.982871
# dtype: float64

# %% [markdown]
# Remove the columns with exteremly high null value percentage.

# %%
to_remove = ['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
df.drop(to_remove, axis=1, inplace=True)

# %%
df.isnull().sum()[df.isnull().sum() > 0] * 100 / len(df)
# Out:
# MSZoning         0.137033
# LotFrontage     16.649538
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrArea       0.787941
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinSF1       0.034258
# BsmtFinType2     2.740665
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# Electrical       0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# KitchenQual      0.034258
# Functional       0.068517
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# GarageQual       5.447071
# GarageCond       5.447071
# SaleType         0.034258
# SalePrice       49.982871
# dtype: float64

# %% [markdown]
# We will split the rest of these columns as <strong>numeric</strong> and <strong>categorical</strong>. We fill use the
# mean or the median for the numeric and the mode for the categorical to fill the missing values.

# %%
null_cols = [col for col in df.columns if df[col].isnull().any()]
null_cols.remove('SalePrice') # We do not want to opearte on this column because we will guess it.

# %%
null_cols
# Out:
# ['MSZoning',
#  'LotFrontage',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Electrical',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'SaleType']

# %%
null_objects = [col for col in null_cols if df[col].dtype == 'object']
null_numeric = [col for col in null_cols if df[col].dtype != 'object']

# %%
null_objects
# Out:
# ['MSZoning',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'SaleType']

# %%
null_numeric
# Out:
# ['LotFrontage',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea']

# %%
for object_col in null_objects:
    mode = df[object_col].mode()[0]
    df[object_col].fillna(mode, inplace=True)

# %%
for numeric_col in null_numeric:
    print(df[numeric_col].describe())
# Out:
# count    2433.000000
# mean       69.305795
# std        23.344905
# min        21.000000
# 25%        59.000000
# 50%        68.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64
# count    2896.000000
# mean      102.201312
# std       179.334253
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       164.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64
# count    2918.000000
# mean      441.423235
# std       455.610826
# min         0.000000
# 25%         0.000000
# 50%       368.500000
# 75%       733.000000
# max      5644.000000
# Name: BsmtFinSF1, dtype: float64
# count    2918.000000
# mean       49.582248
# std       169.205611
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max      1526.000000
# Name: BsmtFinSF2, dtype: float64
# count    2918.000000
# mean      560.772104
# std       439.543659
# min         0.000000
# 25%       220.000000
# 50%       467.000000
# 75%       805.500000
# max      2336.000000
# Name: BsmtUnfSF, dtype: float64
# count    2918.000000
# mean     1051.777587
# std       440.766258
# min         0.000000
# 25%       793.000000
# 50%       989.500000
# 75%      1302.000000
# max      6110.000000
# Name: TotalBsmtSF, dtype: float64
# count    2917.000000
# mean        0.429894
# std         0.524736
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: BsmtFullBath, dtype: float64
# count    2917.000000
# mean        0.061364
# std         0.245687
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         2.000000
# Name: BsmtHalfBath, dtype: float64
# count    2760.000000
# mean     1978.113406
# std        25.574285
# min      1895.000000
# 25%      1960.000000
# 50%      1979.000000
# 75%      2002.000000
# max      2207.000000
# Name: GarageYrBlt, dtype: float64
# count    2918.000000
# mean        1.766621
# std         0.761624
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         5.000000
# Name: GarageCars, dtype: float64
# count    2918.000000
# mean      472.874572
# std       215.394815
# min         0.000000
# 25%       320.000000
# 50%       480.000000
# 75%       576.000000
# max      1488.000000
# Name: GarageArea, dtype: float64

# %% [markdown]
# Most of these columns have a rather large standard deviation. We will fill with the median value.

# %%
for num_col in null_numeric:
    df[num_col].fillna(df[num_col].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage         0
# LotArea             0
# Street              0
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrArea          0
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtCond            0
# BsmtExposure        0
# BsmtFinType1        0
# BsmtFinSF1          0
# BsmtFinType2        0
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          0
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# GarageType          0
# GarageYrBlt         0
# GarageFinish        0
# GarageCars          0
# GarageArea          0
# GarageQual          0
# GarageCond          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice        1459
# dtype: int64

# %% [markdown]
# And with that all the null values are handled. Lets see the correlation with the final state of the columns.

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(35, 20))
sns.heatmap(corr, annot=True);

# %% [markdown]
# ## Modelling

# %%
from sklearn.tree import DecisionTreeRegressor as dtr
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import r2_score, mean_squared_error

# %%
d = dtr()
r = Ridge()
l = Lasso()
en = ElasticNet()
rfr = RandomForestRegressor()
gbr = GradientBoostingRegressor()
svr = SVR()

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.shape
# Out:
# (2919, 230)

# %%
train = df[:trsize]
train.isnull().sum()
# Out:
# MSSubClass               0
# LotFrontage              0
# LotArea                  0
# OverallQual              0
# OverallCond              0
# YearBuilt                0
# YearRemodAdd             0
# MasVnrArea               0
# BsmtFinSF1               0
# BsmtFinSF2               0
# BsmtUnfSF                0
# TotalBsmtSF              0
# 1stFlrSF                 0
# 2ndFlrSF                 0
# LowQualFinSF             0
# GrLivArea                0
# BsmtFullBath             0
# BsmtHalfBath             0
# FullBath                 0
# HalfBath                 0
# BedroomAbvGr             0
# KitchenAbvGr             0
# TotRmsAbvGrd             0
# Fireplaces               0
# GarageYrBlt              0
# GarageCars               0
# GarageArea               0
# WoodDeckSF               0
# OpenPorchSF              0
# EnclosedPorch            0
# 3SsnPorch                0
# ScreenPorch              0
# PoolArea                 0
# MiscVal                  0
# MoSold                   0
# YrSold                   0
# SalePrice                0
# MSZoning_FV              0
# MSZoning_RH              0
# MSZoning_RL              0
# MSZoning_RM              0
# Street_Pave              0
# LotShape_IR2             0
# LotShape_IR3             0
# LotShape_Reg             0
# LandContour_HLS          0
# LandContour_Low          0
# LandContour_Lvl          0
# Utilities_NoSeWa         0
# LotConfig_CulDSac        0
# LotConfig_FR2            0
# LotConfig_FR3            0
# LotConfig_Inside         0
# LandSlope_Mod            0
# LandSlope_Sev            0
# Neighborhood_Blueste     0
# Neighborhood_BrDale      0
# Neighborhood_BrkSide     0
# Neighborhood_ClearCr     0
# Neighborhood_CollgCr     0
# Neighborhood_Crawfor     0
# Neighborhood_Edwards     0
# Neighborhood_Gilbert     0
# Neighborhood_IDOTRR      0
# Neighborhood_MeadowV     0
# Neighborhood_Mitchel     0
# Neighborhood_NAmes       0
# Neighborhood_NPkVill     0
# Neighborhood_NWAmes      0
# Neighborhood_NoRidge     0
# Neighborhood_NridgHt     0
# Neighborhood_OldTown     0
# Neighborhood_SWISU       0
# Neighborhood_Sawyer      0
# Neighborhood_SawyerW     0
# Neighborhood_Somerst     0
# Neighborhood_StoneBr     0
# Neighborhood_Timber      0
# Neighborhood_Veenker     0
# Condition1_Feedr         0
# Condition1_Norm          0
# Condition1_PosA          0
# Condition1_PosN          0
# Condition1_RRAe          0
# Condition1_RRAn          0
# Condition1_RRNe          0
# Condition1_RRNn          0
# Condition2_Feedr         0
# Condition2_Norm          0
# Condition2_PosA          0
# Condition2_PosN          0
# Condition2_RRAe          0
# Condition2_RRAn          0
# Condition2_RRNn          0
# BldgType_2fmCon          0
# BldgType_Duplex          0
# BldgType_Twnhs           0
# BldgType_TwnhsE          0
# HouseStyle_1.5Unf        0
# HouseStyle_1Story        0
# HouseStyle_2.5Fin        0
# HouseStyle_2.5Unf        0
# HouseStyle_2Story        0
# HouseStyle_SFoyer        0
# HouseStyle_SLvl          0
# RoofStyle_Gable          0
# RoofStyle_Gambrel        0
# RoofStyle_Hip            0
# RoofStyle_Mansard        0
# RoofStyle_Shed           0
# RoofMatl_CompShg         0
# RoofMatl_Membran         0
# RoofMatl_Metal           0
# RoofMatl_Roll            0
# RoofMatl_Tar&Grv         0
# RoofMatl_WdShake         0
# RoofMatl_WdShngl         0
# Exterior1st_AsphShn      0
# Exterior1st_BrkComm      0
# Exterior1st_BrkFace      0
# Exterior1st_CBlock       0
# Exterior1st_CemntBd      0
# Exterior1st_HdBoard      0
# Exterior1st_ImStucc      0
# Exterior1st_MetalSd      0
# Exterior1st_Plywood      0
# Exterior1st_Stone        0
# Exterior1st_Stucco       0
# Exterior1st_VinylSd      0
# Exterior1st_Wd Sdng      0
# Exterior1st_WdShing      0
# Exterior2nd_AsphShn      0
# Exterior2nd_Brk Cmn      0
# Exterior2nd_BrkFace      0
# Exterior2nd_CBlock       0
# Exterior2nd_CmentBd      0
# Exterior2nd_HdBoard      0
# Exterior2nd_ImStucc      0
# Exterior2nd_MetalSd      0
# Exterior2nd_Other        0
# Exterior2nd_Plywood      0
# Exterior2nd_Stone        0
# Exterior2nd_Stucco       0
# Exterior2nd_VinylSd      0
# Exterior2nd_Wd Sdng      0
# Exterior2nd_Wd Shng      0
# ExterQual_Fa             0
# ExterQual_Gd             0
# ExterQual_TA             0
# ExterCond_Fa             0
# ExterCond_Gd             0
# ExterCond_Po             0
# ExterCond_TA             0
# Foundation_CBlock        0
# Foundation_PConc         0
# Foundation_Slab          0
# Foundation_Stone         0
# Foundation_Wood          0
# BsmtQual_Fa              0
# BsmtQual_Gd              0
# BsmtQual_TA              0
# BsmtCond_Gd              0
# BsmtCond_Po              0
# BsmtCond_TA              0
# BsmtExposure_Gd          0
# BsmtExposure_Mn          0
# BsmtExposure_No          0
# BsmtFinType1_BLQ         0
# BsmtFinType1_GLQ         0
# BsmtFinType1_LwQ         0
# BsmtFinType1_Rec         0
# BsmtFinType1_Unf         0
# BsmtFinType2_BLQ         0
# BsmtFinType2_GLQ         0
# BsmtFinType2_LwQ         0
# BsmtFinType2_Rec         0
# BsmtFinType2_Unf         0
# Heating_GasA             0
# Heating_GasW             0
# Heating_Grav             0
# Heating_OthW             0
# Heating_Wall             0
# HeatingQC_Fa             0
# HeatingQC_Gd             0
# HeatingQC_Po             0
# HeatingQC_TA             0
# CentralAir_Y             0
# Electrical_FuseF         0
# Electrical_FuseP         0
# Electrical_Mix           0
# Electrical_SBrkr         0
# KitchenQual_Fa           0
# KitchenQual_Gd           0
# KitchenQual_TA           0
# Functional_Maj2          0
# Functional_Min1          0
# Functional_Min2          0
# Functional_Mod           0
# Functional_Sev           0
# Functional_Typ           0
# GarageType_Attchd        0
# GarageType_Basment       0
# GarageType_BuiltIn       0
# GarageType_CarPort       0
# GarageType_Detchd        0
# GarageFinish_RFn         0
# GarageFinish_Unf         0
# GarageQual_Fa            0
# GarageQual_Gd            0
# GarageQual_Po            0
# GarageQual_TA            0
# GarageCond_Fa            0
# GarageCond_Gd            0
# GarageCond_Po            0
# GarageCond_TA            0
# PavedDrive_P             0
# PavedDrive_Y             0
# SaleType_CWD             0
# SaleType_Con             0
# SaleType_ConLD           0
# SaleType_ConLI           0
# SaleType_ConLw           0
# SaleType_New             0
# SaleType_Oth             0
# SaleType_WD              0
# SaleCondition_AdjLand    0
# SaleCondition_Alloca     0
# SaleCondition_Family     0
# SaleCondition_Normal     0
# SaleCondition_Partial    0
# dtype: int64

# %%
x = train.drop('SalePrice', axis=1)
y = train['SalePrice']

# %%
x_train, x_test, y_train, y_test = tts(x, y, random_state=42, test_size=.2)

# %%
def test_models(models, x_train, x_test, y_train, y_test):
    for model in models:
        model.fit(x_train, y_train)
        pred = model.predict(x_test)
        
        rmse = mean_squared_error(y_test, pred)
        print(f'rmse for {str(model)[:-2]} is {rmse}')

        r2 = r2_score(y_test, pred)
        print(f'r2 score for {str(model)[:-2]} is {r2}')
        print()

# %%
test_models([d, r, l, en, rfr, gbr, svr], x_train, x_test, y_train, y_test)
# Out:
# rmse for DecisionTreeRegressor is 1841326378.5821917
# r2 score for DecisionTreeRegressor is 0.759941581512288
#
# rmse for Ridge is 904834324.5144695
# r2 score for Ridge is 0.8820344402475822
#
# rmse for Lasso is 2548497343.353866
# r2 score for Lasso is 0.6677458983470723
#
# rmse for ElasticNet is 1267923145.02631
# r2 score for ElasticNet is 0.8346976242238223
#
# rmse for RandomForestRegressor is 828619820.3729202
# r2 score for RandomForestRegressor is 0.8919707196290426
#
# rmse for GradientBoostingRegressor is 796074494.0884577
# r2 score for GradientBoostingRegressor is 0.896213736862647
#
# rmse for SVR is 7859358017.438961
# r2 score for SVR is -0.024644559454943815

# %% [markdown]
# Gradient boosting regressor and random forest regressor are the best performers. Lets use GradientBoostingRegressor to predict the actual missing data.

# %%
train_actual = df[:trsize]
test_actual = df[trsize:]

# %%
x = train_actual.drop('SalePrice', axis=1) # The train file without the sale price column.
y = train_actual['SalePrice'] # only the sale price column of the train.

# %%
model = gbr.fit(x, y)
pred = model.predict(test_actual.drop('SalePrice', axis=1))

# %% [markdown]
# View the predicted values.

# %%
pred
# Out:
# array([119456.75827164, 163533.02391205, 174674.57936412, ...,
#        171177.29722756, 119729.36596988, 243778.76380398])

# %% [markdown]
# #### Filling the missing values with the prediction and saving the final set

# %%
test_actual['SalePrice'].fillna(pd.Series(pred, index=test_actual.index), inplace=True)

# %%
final_result = pd.concat([train_actual, test_actual])

# %%
final_result.sample(10)
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 94            20        100.0    15263            5            5       1959
# 569           90         68.0     7032            5            5       1979
# 425           60         60.0     3378            7            8       1946
# 428           20         64.0     6762            7            5       2007
# 813           20         80.0    10400            6            5       1979
# 960           20         75.0     9532            4            6       1953
# 633           30         60.0     5400            7            6       1920
# 763           60         68.0    11050            7            5       1996
# 1245          80         78.0    12090            6            7       1984
# 903           20         43.0    12712            6            7       1973
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 94            1959        90.0       766.0         0.0      656.0
# 569           1979         0.0       943.0         0.0        0.0
# 425           1992         0.0         0.0         0.0      651.0
# 428           2007       108.0       664.0         0.0      544.0
# 813           1999       253.0       903.0         0.0      356.0
# 960           1953         0.0       595.0       354.0      156.0
# 633           2006         0.0         0.0         0.0      931.0
# 763           1997         0.0         0.0         0.0      910.0
# 1245          2003        74.0         0.0         0.0      585.0
# 903           2006         0.0       968.0         0.0       76.0
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 94         1422.0      1675         0             0       1675           0.0
# 569         943.0       943         0             0        943           1.0
# 425         651.0       707       682             0       1389           0.0
# 428        1208.0      1208         0             0       1208           1.0
# 813        1259.0      1353         0             0       1353           1.0
# 960        1105.0      1647         0             0       1647           1.0
# 633         931.0      1027         0             0       1027           0.0
# 763         910.0       910       910             0       1820           0.0
# 1245        585.0      1140       728             0       1868           0.0
# 903        1044.0      1055         0             0       1055           1.0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 94             0.0         2         0             3             1
# 569            0.0         1         0             2             1
# 425            0.0         1         1             3             1
# 428            0.0         2         0             2             1
# 813            0.0         2         0             2             1
# 960            0.0         1         0             3             1
# 633            1.0         1         0             2             1
# 763            0.0         2         1             3             1
# 1245           0.0         3         1             3             1
# 903            0.0         1         0             2             1
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  GarageArea  \
# 94               8           2       1959.0         1.0       365.0
# 569              4           2       1979.0         2.0       600.0
# 425              6           2       1947.0         1.0       240.0
# 428              6           0       2007.0         2.0       628.0
# 813              5           1       1979.0         2.0       478.0
# 960              6           1       1953.0         1.0       280.0
# 633              5           1       1979.0         0.0         0.0
# 763              8           1       1996.0         3.0       816.0
# 1245             7           1       1984.0         2.0       477.0
# 903              5           1       1973.0         2.0       542.0
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 94             0          132              0          0            0
# 569           42            0              0          0            0
# 425            0            0            126          0            0
# 428          105           54              0          0            0
# 813          240          141              0          0            0
# 960          225            0              0          0            0
# 633            0           28              0          0            0
# 763          318           32              0          0            0
# 1245         268          112              0          0          147
# 903          455            0              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold      SalePrice  MSZoning_FV  \
# 94           0        0       5    2010  162972.142221        False
# 569          0        0      12    2006  135960.000000        False
# 425          0        0       9    2009  135000.000000        False
# 428          0        0       9    2007  195400.000000        False
# 813          0        0       8    2007  170118.301972        False
# 960        368        0       2    2007  151526.947632        False
# 633          0        0       2    2008  140041.654708        False
# 763          0        0       9    2008  210425.659312        False
# 1245         0        0       1    2007  178000.000000        False
# 903          0        0       1    2007  168300.022056        False
#
#       MSZoning_RH  MSZoning_RL  MSZoning_RM  Street_Pave  LotShape_IR2  \
# 94          False         True        False         True         False
# 569         False         True        False         True         False
# 425         False        False         True         True         False
# 428         False         True        False         True         False
# 813         False         True        False         True         False
# 960         False         True        False         True         False
# 633         False        False         True         True         False
# 763         False         True        False         True         False
# 1245        False         True        False         True         False
# 903         False         True        False         True         False
#
#       LotShape_IR3  LotShape_Reg  LandContour_HLS  LandContour_Low  \
# 94           False         False            False            False
# 569          False         False            False            False
# 425          False          True             True            False
# 428          False          True            False            False
# 813          False          True            False            False
# 960          False          True            False            False
# 633          False          True            False            False
# 763          False          True            False            False
# 1245         False          True            False            False
# 903          False         False            False            False
#
#       LandContour_Lvl  Utilities_NoSeWa  LotConfig_CulDSac  LotConfig_FR2  \
# 94               True             False              False          False
# 569              True             False              False          False
# 425             False             False              False          False
# 428              True             False              False          False
# 813              True             False              False          False
# 960              True             False              False          False
# 633              True             False              False          False
# 763              True             False              False          False
# 1245             True             False              False          False
# 903              True             False               True          False
#
#       LotConfig_FR3  LotConfig_Inside  LandSlope_Mod  LandSlope_Sev  \
# 94            False              True          False          False
# 569           False             False          False          False
# 425           False              True          False          False
# 428           False              True          False          False
# 813           False              True          False          False
# 960           False              True          False          False
# 633           False              True          False          False
# 763           False              True          False          False
# 1245          False              True          False          False
# 903           False             False          False          False
#
#       Neighborhood_Blueste  Neighborhood_BrDale  Neighborhood_BrkSide  \
# 94                   False                False                 False
# 569                  False                False                 False
# 425                  False                False                 False
# 428                  False                False                 False
# 813                  False                False                 False
# 960                  False                False                 False
# 633                  False                False                 False
# 763                  False                False                 False
# 1245                 False                False                 False
# 903                  False                False                 False
#
#       Neighborhood_ClearCr  Neighborhood_CollgCr  Neighborhood_Crawfor  \
# 94                    True                 False                 False
# 569                  False                 False                 False
# 425                  False                 False                 False
# 428                  False                  True                 False
# 813                  False                 False                 False
# 960                  False                 False                 False
# 633                  False                 False                 False
# 763                  False                 False                 False
# 1245                 False                 False                 False
# 903                  False                 False                 False
#
#       Neighborhood_Edwards  Neighborhood_Gilbert  Neighborhood_IDOTRR  \
# 94                   False                 False                False
# 569                  False                 False                False
# 425                  False                 False                False
# 428                  False                 False                False
# 813                  False                 False                False
# 960                  False                 False                False
# 633                  False                 False                False
# 763                  False                 False                False
# 1245                 False                 False                False
# 903                  False                 False                False
#
#       Neighborhood_MeadowV  Neighborhood_Mitchel  Neighborhood_NAmes  \
# 94                   False                 False               False
# 569                  False                 False                True
# 425                  False                 False               False
# 428                  False                 False               False
# 813                  False                 False               False
# 960                  False                 False                True
# 633                  False                 False               False
# 763                  False                  True               False
# 1245                 False                 False               False
# 903                  False                 False               False
#
#       Neighborhood_NPkVill  Neighborhood_NWAmes  Neighborhood_NoRidge  \
# 94                   False                False                 False
# 569                  False                False                 False
# 425                  False                False                 False
# 428                  False                False                 False
# 813                  False                 True                 False
# 960                  False                False                 False
# 633                  False                False                 False
# 763                  False                False                 False
# 1245                 False                 True                 False
# 903                  False                False                 False
#
#       Neighborhood_NridgHt  Neighborhood_OldTown  Neighborhood_SWISU  \
# 94                   False                 False               False
# 569                  False                 False               False
# 425                  False                  True               False
# 428                  False                 False               False
# 813                  False                 False               False
# 960                  False                 False               False
# 633                  False                  True               False
# 763                  False                 False               False
# 1245                 False                 False               False
# 903                  False                 False               False
#
#       Neighborhood_Sawyer  Neighborhood_SawyerW  Neighborhood_Somerst  \
# 94                  False                 False                 False
# 569                 False                 False                 False
# 425                 False                 False                 False
# 428                 False                 False                 False
# 813                 False                 False                 False
# 960                 False                 False                 False
# 633                 False                 False                 False
# 763                 False                 False                 False
# 1245                False                 False                 False
# 903                  True                 False                 False
#
#       Neighborhood_StoneBr  Neighborhood_Timber  Neighborhood_Veenker  \
# 94                   False                False                 False
# 569                  False                False                 False
# 425                  False                False                 False
# 428                  False                False                 False
# 813                  False                False                 False
# 960                  False                False                 False
# 633                  False                False                 False
# 763                  False                False                 False
# 1245                 False                False                 False
# 903                  False                False                 False
#
#       Condition1_Feedr  Condition1_Norm  Condition1_PosA  Condition1_PosN  \
# 94                True            False            False            False
# 569              False             True            False            False
# 425              False             True            False            False
# 428              False             True            False            False
# 813              False             True            False            False
# 960              False             True            False            False
# 633              False             True            False            False
# 763              False             True            False            False
# 1245             False             True            False            False
# 903              False            False            False            False
#
#       Condition1_RRAe  Condition1_RRAn  Condition1_RRNe  Condition1_RRNn  \
# 94              False            False            False            False
# 569             False            False            False            False
# 425             False            False            False            False
# 428             False            False            False            False
# 813             False            False            False            False
# 960             False            False            False            False
# 633             False            False            False            False
# 763             False            False            False            False
# 1245            False            False            False            False
# 903              True            False            False            False
#
#       Condition2_Feedr  Condition2_Norm  Condition2_PosA  Condition2_PosN  \
# 94               False             True            False            False
# 569              False             True            False            False
# 425              False             True            False            False
# 428              False             True            False            False
# 813              False             True            False            False
# 960              False             True            False            False
# 633              False             True            False            False
# 763              False             True            False            False
# 1245             False             True            False            False
# 903              False             True            False            False
#
#       Condition2_RRAe  Condition2_RRAn  Condition2_RRNn  BldgType_2fmCon  \
# 94              False            False            False            False
# 569             False            False            False            False
# 425             False            False            False            False
# 428             False            False            False            False
# 813             False            False            False            False
# 960             False            False            False            False
# 633             False            False            False            False
# 763             False            False            False            False
# 1245            False            False            False            False
# 903             False            False            False            False
#
#       BldgType_Duplex  BldgType_Twnhs  BldgType_TwnhsE  HouseStyle_1.5Unf  \
# 94              False           False            False              False
# 569              True           False            False              False
# 425             False           False            False              False
# 428             False           False            False              False
# 813             False           False            False              False
# 960             False           False            False              False
# 633             False           False            False              False
# 763             False           False            False              False
# 1245            False           False            False              False
# 903             False           False            False              False
#
#       HouseStyle_1Story  HouseStyle_2.5Fin  HouseStyle_2.5Unf  \
# 94                 True              False              False
# 569               False              False              False
# 425               False              False              False
# 428                True              False              False
# 813                True              False              False
# 960                True              False              False
# 633                True              False              False
# 763               False              False              False
# 1245              False              False              False
# 903                True              False              False
#
#       HouseStyle_2Story  HouseStyle_SFoyer  HouseStyle_SLvl  RoofStyle_Gable  \
# 94                False              False            False             True
# 569               False               True            False             True
# 425                True              False            False             True
# 428               False              False            False             True
# 813               False              False            False             True
# 960               False              False            False             True
# 633               False              False            False             True
# 763                True              False            False             True
# 1245              False              False             True            False
# 903               False              False            False             True
#
#       RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  RoofStyle_Shed  \
# 94                False          False              False           False
# 569               False          False              False           False
# 425               False          False              False           False
# 428               False          False              False           False
# 813               False          False              False           False
# 960               False          False              False           False
# 633               False          False              False           False
# 763               False          False              False           False
# 1245              False           True              False           False
# 903               False          False              False           False
#
#       RoofMatl_CompShg  RoofMatl_Membran  RoofMatl_Metal  RoofMatl_Roll  \
# 94                True             False           False          False
# 569               True             False           False          False
# 425               True             False           False          False
# 428               True             False           False          False
# 813               True             False           False          False
# 960               True             False           False          False
# 633               True             False           False          False
# 763               True             False           False          False
# 1245              True             False           False          False
# 903               True             False           False          False
#
#       RoofMatl_Tar&Grv  RoofMatl_WdShake  RoofMatl_WdShngl  \
# 94               False             False             False
# 569              False             False             False
# 425              False             False             False
# 428              False             False             False
# 813              False             False             False
# 960              False             False             False
# 633              False             False             False
# 763              False             False             False
# 1245             False             False             False
# 903              False             False             False
#
#       Exterior1st_AsphShn  Exterior1st_BrkComm  Exterior1st_BrkFace  \
# 94                  False                False                False
# 569                 False                False                False
# 425                 False                False                False
# 428                 False                False                False
# 813                 False                False                False
# 960                 False                False                False
# 633                 False                False                False
# 763                 False                False                False
# 1245                False                False                False
# 903                 False                False                False
#
#       Exterior1st_CBlock  Exterior1st_CemntBd  Exterior1st_HdBoard  \
# 94                 False                False                 True
# 569                False                False                False
# 425                False                False                 True
# 428                False                False                False
# 813                False                False                False
# 960                False                False                False
# 633                False                False                False
# 763                False                False                False
# 1245               False                False                False
# 903                False                 True                False
#
#       Exterior1st_ImStucc  Exterior1st_MetalSd  Exterior1st_Plywood  \
# 94                  False                False                False
# 569                 False                 True                False
# 425                 False                False                False
# 428                 False                False                False
# 813                 False                 True                False
# 960                 False                False                False
# 633                 False                False                False
# 763                 False                False                False
# 1245                False                False                False
# 903                 False                False                False
#
#       Exterior1st_Stone  Exterior1st_Stucco  Exterior1st_VinylSd  \
# 94                False               False                False
# 569               False               False                False
# 425               False               False                False
# 428               False               False                 True
# 813               False               False                False
# 960               False               False                 True
# 633               False                True                False
# 763               False               False                 True
# 1245              False               False                 True
# 903               False               False                False
#
#       Exterior1st_Wd Sdng  Exterior1st_WdShing  Exterior2nd_AsphShn  \
# 94                  False                False                False
# 569                 False                False                False
# 425                 False                False                False
# 428                 False                False                False
# 813                 False                False                False
# 960                 False                False                False
# 633                 False                False                False
# 763                 False                False                False
# 1245                False                False                False
# 903                 False                False                False
#
#       Exterior2nd_Brk Cmn  Exterior2nd_BrkFace  Exterior2nd_CBlock  \
# 94                  False                False               False
# 569                 False                False               False
# 425                 False                False               False
# 428                 False                False               False
# 813                 False                False               False
# 960                 False                False               False
# 633                 False                False               False
# 763                 False                False               False
# 1245                False                False               False
# 903                 False                False               False
#
#       Exterior2nd_CmentBd  Exterior2nd_HdBoard  Exterior2nd_ImStucc  \
# 94                  False                 True                False
# 569                 False                False                False
# 425                 False                 True                False
# 428                 False                False                False
# 813                 False                False                False
# 960                 False                False                False
# 633                 False                False                False
# 763                 False                False                False
# 1245                False                False                False
# 903                  True                False                False
#
#       Exterior2nd_MetalSd  Exterior2nd_Other  Exterior2nd_Plywood  \
# 94                  False              False                False
# 569                  True              False                False
# 425                 False              False                False
# 428                 False              False                False
# 813                  True              False                False
# 960                 False              False                False
# 633                 False              False                False
# 763                 False              False                False
# 1245                False              False                False
# 903                 False              False                False
#
#       Exterior2nd_Stone  Exterior2nd_Stucco  Exterior2nd_VinylSd  \
# 94                False               False                False
# 569               False               False                False
# 425               False               False                False
# 428               False               False                 True
# 813               False               False                False
# 960               False               False                 True
# 633               False                True                False
# 763               False               False                 True
# 1245              False               False                 True
# 903               False               False                False
#
#       Exterior2nd_Wd Sdng  Exterior2nd_Wd Shng  ExterQual_Fa  ExterQual_Gd  \
# 94                  False                False         False         False
# 569                 False                False         False         False
# 425                 False                False         False         False
# 428                 False                False         False          True
# 813                 False                False         False         False
# 960                 False                False         False         False
# 633                 False                False         False          True
# 763                 False                False         False         False
# 1245                False                False         False         False
# 903                 False                False         False         False
#
#       ExterQual_TA  ExterCond_Fa  ExterCond_Gd  ExterCond_Po  ExterCond_TA  \
# 94            True         False         False         False          True
# 569           True         False         False         False          True
# 425           True         False          True         False         False
# 428          False         False         False         False          True
# 813           True         False         False         False          True
# 960           True         False         False         False          True
# 633          False         False         False         False          True
# 763           True         False         False         False          True
# 1245          True         False         False         False          True
# 903           True         False         False         False          True
#
#       Foundation_CBlock  Foundation_PConc  Foundation_Slab  Foundation_Stone  \
# 94                 True             False            False             False
# 569                True             False            False             False
# 425                True             False            False             False
# 428               False              True            False             False
# 813                True             False            False             False
# 960                True             False            False             False
# 633                True             False            False             False
# 763               False              True            False             False
# 1245               True             False            False             False
# 903                True             False            False             False
#
#       Foundation_Wood  BsmtQual_Fa  BsmtQual_Gd  BsmtQual_TA  BsmtCond_Gd  \
# 94              False        False         True        False        False
# 569             False        False         True        False        False
# 425             False        False        False         True        False
# 428             False        False         True        False        False
# 813             False        False         True        False        False
# 960             False        False        False         True        False
# 633             False        False        False         True        False
# 763             False        False         True        False        False
# 1245            False        False         True        False        False
# 903             False        False         True        False        False
#
#       BsmtCond_Po  BsmtCond_TA  BsmtExposure_Gd  BsmtExposure_Mn  \
# 94          False         True            False            False
# 569         False         True             True            False
# 425         False         True            False            False
# 428         False         True            False            False
# 813         False         True            False            False
# 960         False         True            False            False
# 633         False         True            False            False
# 763         False         True            False             True
# 1245        False         True            False            False
# 903         False         True            False             True
#
#       BsmtExposure_No  BsmtFinType1_BLQ  BsmtFinType1_GLQ  BsmtFinType1_LwQ  \
# 94               True             False             False             False
# 569             False             False              True             False
# 425              True             False             False             False
# 428              True             False              True             False
# 813              True             False              True             False
# 960              True              True             False             False
# 633              True             False             False             False
# 763             False             False             False             False
# 1245             True             False             False             False
# 903             False             False             False             False
#
#       BsmtFinType1_Rec  BsmtFinType1_Unf  BsmtFinType2_BLQ  BsmtFinType2_GLQ  \
# 94                True             False             False             False
# 569              False             False             False             False
# 425              False              True             False             False
# 428              False             False             False             False
# 813              False             False             False             False
# 960              False             False             False             False
# 633              False              True             False             False
# 763              False              True             False             False
# 1245             False              True             False             False
# 903              False             False             False             False
#
#       BsmtFinType2_LwQ  BsmtFinType2_Rec  BsmtFinType2_Unf  Heating_GasA  \
# 94               False             False              True          True
# 569              False             False              True          True
# 425              False             False              True          True
# 428              False             False              True          True
# 813              False             False              True          True
# 960              False              True             False          True
# 633              False             False              True          True
# 763              False             False              True          True
# 1245             False             False              True          True
# 903              False             False              True          True
#
#       Heating_GasW  Heating_Grav  Heating_OthW  Heating_Wall  HeatingQC_Fa  \
# 94           False         False         False         False         False
# 569          False         False         False         False         False
# 425          False         False         False         False         False
# 428          False         False         False         False         False
# 813          False         False         False         False         False
# 960          False         False         False         False         False
# 633          False         False         False         False         False
# 763          False         False         False         False         False
# 1245         False         False         False         False         False
# 903          False         False         False         False         False
#
#       HeatingQC_Gd  HeatingQC_Po  HeatingQC_TA  CentralAir_Y  \
# 94            True         False         False          True
# 569          False         False          True          True
# 425           True         False         False          True
# 428          False         False         False          True
# 813          False         False         False          True
# 960           True         False         False          True
# 633          False         False          True          True
# 763          False         False         False          True
# 1245         False         False         False          True
# 903          False         False          True          True
#
#       Electrical_FuseF  Electrical_FuseP  Electrical_Mix  Electrical_SBrkr  \
# 94               False             False           False              True
# 569              False             False           False              True
# 425              False             False           False              True
# 428              False             False           False              True
# 813              False             False           False              True
# 960              False             False           False              True
# 633              False             False           False              True
# 763              False             False           False              True
# 1245             False             False           False              True
# 903              False             False           False              True
#
#       KitchenQual_Fa  KitchenQual_Gd  KitchenQual_TA  Functional_Maj2  \
# 94             False           False            True            False
# 569            False           False            True            False
# 425            False           False            True            False
# 428            False            True           False            False
# 813            False           False            True            False
# 960            False           False            True            False
# 633            False            True           False            False
# 763            False            True           False            False
# 1245           False           False            True            False
# 903            False            True           False            False
#
#       Functional_Min1  Functional_Min2  Functional_Mod  Functional_Sev  \
# 94              False            False           False           False
# 569             False            False           False           False
# 425             False            False           False           False
# 428             False            False           False           False
# 813             False            False           False           False
# 960              True            False           False           False
# 633             False            False           False           False
# 763             False            False           False           False
# 1245            False            False           False           False
# 903             False            False           False           False
#
#       Functional_Typ  GarageType_Attchd  GarageType_Basment  \
# 94              True               True               False
# 569             True              False               False
# 425             True              False               False
# 428             True               True               False
# 813             True               True               False
# 960            False               True               False
# 633             True               True               False
# 763             True               True               False
# 1245            True              False               False
# 903             True               True               False
#
#       GarageType_BuiltIn  GarageType_CarPort  GarageType_Detchd  \
# 94                 False               False              False
# 569                False               False               True
# 425                False               False               True
# 428                False               False              False
# 813                False               False              False
# 960                False               False              False
# 633                False               False              False
# 763                False               False              False
# 1245                True               False              False
# 903                False               False              False
#
#       GarageFinish_RFn  GarageFinish_Unf  GarageQual_Fa  GarageQual_Gd  \
# 94               False              True          False          False
# 569              False              True          False          False
# 425              False              True          False          False
# 428               True             False          False          False
# 813               True             False          False          False
# 960              False             False          False          False
# 633              False              True          False          False
# 763              False              True          False          False
# 1245             False             False          False          False
# 903               True             False          False          False
#
#       GarageQual_Po  GarageQual_TA  GarageCond_Fa  GarageCond_Gd  \
# 94            False           True          False          False
# 569           False           True          False          False
# 425           False           True          False          False
# 428           False           True          False          False
# 813           False           True          False          False
# 960           False           True          False          False
# 633           False           True          False          False
# 763           False           True          False          False
# 1245          False           True          False          False
# 903           False           True          False          False
#
#       GarageCond_Po  GarageCond_TA  PavedDrive_P  PavedDrive_Y  SaleType_CWD  \
# 94            False           True         False          True         False
# 569           False           True         False          True         False
# 425           False           True          True         False         False
# 428           False           True         False          True         False
# 813           False           True         False          True         False
# 960           False           True         False          True         False
# 633           False           True         False         False         False
# 763           False           True         False          True         False
# 1245          False           True         False          True         False
# 903           False           True         False          True         False
#
#       SaleType_Con  SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  \
# 94           False           False           False           False
# 569          False           False           False           False
# 425          False           False           False           False
# 428          False           False           False           False
# 813          False           False           False           False
# 960          False           False           False           False
# 633          False           False           False           False
# 763          False           False           False           False
# 1245         False           False           False           False
# 903          False           False           False           False
#
#       SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_AdjLand  \
# 94           False         False         True                  False
# 569          False         False         True                  False
# 425          False         False         True                  False
# 428           True         False        False                  False
# 813          False         False         True                  False
# 960          False         False         True                  False
# 633          False         False         True                  False
# 763          False         False         True                  False
# 1245         False         False         True                  False
# 903          False         False         True                  False
#
#       SaleCondition_Alloca  SaleCondition_Family  SaleCondition_Normal  \
# 94                   False                 False                  True
# 569                  False                 False                  True
# 425                  False                 False                  True
# 428                  False                 False                 False
# 813                  False                 False                  True
# 960                  False                 False                  True
# 633                  False                 False                  True
# 763                  False                 False                  True
# 1245                 False                 False                 False
# 903                  False                 False                 False
#
#       SaleCondition_Partial
# 94                    False
# 569                   False
# 425                   False
# 428                    True
# 813                   False
# 960                   False
# 633                   False
# 763                   False
# 1245                  False
# 903                   False

# %% [markdown]
# To confirm there are no null values in the final result:

# %%
final_result.isnull().sum()
# Out:
# MSSubClass               0
# LotFrontage              0
# LotArea                  0
# OverallQual              0
# OverallCond              0
# YearBuilt                0
# YearRemodAdd             0
# MasVnrArea               0
# BsmtFinSF1               0
# BsmtFinSF2               0
# BsmtUnfSF                0
# TotalBsmtSF              0
# 1stFlrSF                 0
# 2ndFlrSF                 0
# LowQualFinSF             0
# GrLivArea                0
# BsmtFullBath             0
# BsmtHalfBath             0
# FullBath                 0
# HalfBath                 0
# BedroomAbvGr             0
# KitchenAbvGr             0
# TotRmsAbvGrd             0
# Fireplaces               0
# GarageYrBlt              0
# GarageCars               0
# GarageArea               0
# WoodDeckSF               0
# OpenPorchSF              0
# EnclosedPorch            0
# 3SsnPorch                0
# ScreenPorch              0
# PoolArea                 0
# MiscVal                  0
# MoSold                   0
# YrSold                   0
# SalePrice                0
# MSZoning_FV              0
# MSZoning_RH              0
# MSZoning_RL              0
# MSZoning_RM              0
# Street_Pave              0
# LotShape_IR2             0
# LotShape_IR3             0
# LotShape_Reg             0
# LandContour_HLS          0
# LandContour_Low          0
# LandContour_Lvl          0
# Utilities_NoSeWa         0
# LotConfig_CulDSac        0
# LotConfig_FR2            0
# LotConfig_FR3            0
# LotConfig_Inside         0
# LandSlope_Mod            0
# LandSlope_Sev            0
# Neighborhood_Blueste     0
# Neighborhood_BrDale      0
# Neighborhood_BrkSide     0
# Neighborhood_ClearCr     0
# Neighborhood_CollgCr     0
# Neighborhood_Crawfor     0
# Neighborhood_Edwards     0
# Neighborhood_Gilbert     0
# Neighborhood_IDOTRR      0
# Neighborhood_MeadowV     0
# Neighborhood_Mitchel     0
# Neighborhood_NAmes       0
# Neighborhood_NPkVill     0
# Neighborhood_NWAmes      0
# Neighborhood_NoRidge     0
# Neighborhood_NridgHt     0
# Neighborhood_OldTown     0
# Neighborhood_SWISU       0
# Neighborhood_Sawyer      0
# Neighborhood_SawyerW     0
# Neighborhood_Somerst     0
# Neighborhood_StoneBr     0
# Neighborhood_Timber      0
# Neighborhood_Veenker     0
# Condition1_Feedr         0
# Condition1_Norm          0
# Condition1_PosA          0
# Condition1_PosN          0
# Condition1_RRAe          0
# Condition1_RRAn          0
# Condition1_RRNe          0
# Condition1_RRNn          0
# Condition2_Feedr         0
# Condition2_Norm          0
# Condition2_PosA          0
# Condition2_PosN          0
# Condition2_RRAe          0
# Condition2_RRAn          0
# Condition2_RRNn          0
# BldgType_2fmCon          0
# BldgType_Duplex          0
# BldgType_Twnhs           0
# BldgType_TwnhsE          0
# HouseStyle_1.5Unf        0
# HouseStyle_1Story        0
# HouseStyle_2.5Fin        0
# HouseStyle_2.5Unf        0
# HouseStyle_2Story        0
# HouseStyle_SFoyer        0
# HouseStyle_SLvl          0
# RoofStyle_Gable          0
# RoofStyle_Gambrel        0
# RoofStyle_Hip            0
# RoofStyle_Mansard        0
# RoofStyle_Shed           0
# RoofMatl_CompShg         0
# RoofMatl_Membran         0
# RoofMatl_Metal           0
# RoofMatl_Roll            0
# RoofMatl_Tar&Grv         0
# RoofMatl_WdShake         0
# RoofMatl_WdShngl         0
# Exterior1st_AsphShn      0
# Exterior1st_BrkComm      0
# Exterior1st_BrkFace      0
# Exterior1st_CBlock       0
# Exterior1st_CemntBd      0
# Exterior1st_HdBoard      0
# Exterior1st_ImStucc      0
# Exterior1st_MetalSd      0
# Exterior1st_Plywood      0
# Exterior1st_Stone        0
# Exterior1st_Stucco       0
# Exterior1st_VinylSd      0
# Exterior1st_Wd Sdng      0
# Exterior1st_WdShing      0
# Exterior2nd_AsphShn      0
# Exterior2nd_Brk Cmn      0
# Exterior2nd_BrkFace      0
# Exterior2nd_CBlock       0
# Exterior2nd_CmentBd      0
# Exterior2nd_HdBoard      0
# Exterior2nd_ImStucc      0
# Exterior2nd_MetalSd      0
# Exterior2nd_Other        0
# Exterior2nd_Plywood      0
# Exterior2nd_Stone        0
# Exterior2nd_Stucco       0
# Exterior2nd_VinylSd      0
# Exterior2nd_Wd Sdng      0
# Exterior2nd_Wd Shng      0
# ExterQual_Fa             0
# ExterQual_Gd             0
# ExterQual_TA             0
# ExterCond_Fa             0
# ExterCond_Gd             0
# ExterCond_Po             0
# ExterCond_TA             0
# Foundation_CBlock        0
# Foundation_PConc         0
# Foundation_Slab          0
# Foundation_Stone         0
# Foundation_Wood          0
# BsmtQual_Fa              0
# BsmtQual_Gd              0
# BsmtQual_TA              0
# BsmtCond_Gd              0
# BsmtCond_Po              0
# BsmtCond_TA              0
# BsmtExposure_Gd          0
# BsmtExposure_Mn          0
# BsmtExposure_No          0
# BsmtFinType1_BLQ         0
# BsmtFinType1_GLQ         0
# BsmtFinType1_LwQ         0
# BsmtFinType1_Rec         0
# BsmtFinType1_Unf         0
# BsmtFinType2_BLQ         0
# BsmtFinType2_GLQ         0
# BsmtFinType2_LwQ         0
# BsmtFinType2_Rec         0
# BsmtFinType2_Unf         0
# Heating_GasA             0
# Heating_GasW             0
# Heating_Grav             0
# Heating_OthW             0
# Heating_Wall             0
# HeatingQC_Fa             0
# HeatingQC_Gd             0
# HeatingQC_Po             0
# HeatingQC_TA             0
# CentralAir_Y             0
# Electrical_FuseF         0
# Electrical_FuseP         0
# Electrical_Mix           0
# Electrical_SBrkr         0
# KitchenQual_Fa           0
# KitchenQual_Gd           0
# KitchenQual_TA           0
# Functional_Maj2          0
# Functional_Min1          0
# Functional_Min2          0
# Functional_Mod           0
# Functional_Sev           0
# Functional_Typ           0
# GarageType_Attchd        0
# GarageType_Basment       0
# GarageType_BuiltIn       0
# GarageType_CarPort       0
# GarageType_Detchd        0
# GarageFinish_RFn         0
# GarageFinish_Unf         0
# GarageQual_Fa            0
# GarageQual_Gd            0
# GarageQual_Po            0
# GarageQual_TA            0
# GarageCond_Fa            0
# GarageCond_Gd            0
# GarageCond_Po            0
# GarageCond_TA            0
# PavedDrive_P             0
# PavedDrive_Y             0
# SaleType_CWD             0
# SaleType_Con             0
# SaleType_ConLD           0
# SaleType_ConLI           0
# SaleType_ConLw           0
# SaleType_New             0
# SaleType_Oth             0
# SaleType_WD              0
# SaleCondition_AdjLand    0
# SaleCondition_Alloca     0
# SaleCondition_Family     0
# SaleCondition_Normal     0
# SaleCondition_Partial    0
# dtype: int64

# %%
final_result.to_csv('predictions.csv', index=False)
