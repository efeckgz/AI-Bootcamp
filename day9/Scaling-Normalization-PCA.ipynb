# %% [markdown]
# # Scaling - Normalization - PCA

# %%
import pandas as pd

# %%
df = pd.read_csv('pima-indians-diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# All the values in this table are of different metrics. Age is measured in years, SkinThicness is in mms etc. Scaling is the process of taking these values and scaling them into a common metric.

# %%
from sklearn.preprocessing import normalize, scale

# %%
x = df.drop('Outcome', axis=1) # We do not normalize the target column.

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
x = scale(x)

# %%
pd.DataFrame(x)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.639947  0.848324  0.149641  0.907270 -0.692891  0.204013  0.468492
# 1   -0.844885 -1.123396 -0.160546  0.530902 -0.692891 -0.684422 -0.365061
# 2    1.233880  1.943724 -0.263941 -1.288212 -0.692891 -1.103255  0.604397
# 3   -0.844885 -0.998208 -0.160546  0.154533  0.123302 -0.494043 -0.920763
# 4   -1.141852  0.504055 -1.504687  0.907270  0.765836  1.409746  5.484909
# ..        ...       ...       ...       ...       ...       ...       ...
# 763  1.827813 -0.622642  0.356432  1.722735  0.870031  0.115169 -0.908682
# 764 -0.547919  0.034598  0.046245  0.405445 -0.692891  0.610154 -0.398282
# 765  0.342981  0.003301  0.149641  0.154533  0.279594 -0.735190 -0.685193
# 766 -0.844885  0.159787 -0.470732 -1.288212 -0.692891 -0.240205 -0.371101
# 767 -0.844885 -0.873019  0.046245  0.656358 -0.692891 -0.202129 -0.473785
#
#             7
# 0    1.425995
# 1   -0.190672
# 2   -0.105584
# 3   -1.041549
# 4   -0.020496
# ..        ...
# 763  2.532136
# 764 -0.531023
# 765 -0.275760
# 766  1.170732
# 767 -0.871374
#
# [768 rows x 8 columns]

# %% [markdown]
# The resulting table here represents the values of the original table.

# %%
norm = normalize(x)

# %%
pd.DataFrame(norm)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.293647  0.389263  0.068664  0.416311 -0.317941  0.093614  0.214973
# 1   -0.458093 -0.609101 -0.087047  0.287852 -0.375682 -0.371091 -0.197934
# 2    0.408951  0.644218 -0.087479 -0.426959 -0.229648 -0.365657  0.200318
# 3   -0.425010 -0.502137 -0.080761  0.077736  0.062026 -0.248523 -0.463179
# 4   -0.186954  0.082528 -0.246360  0.148546  0.125389  0.230816  0.898036
# ..        ...       ...       ...       ...       ...       ...       ...
# 763  0.474619 -0.161678  0.092553  0.447334  0.225917  0.029905 -0.235953
# 764 -0.412899  0.026072  0.034849  0.305535 -0.522147  0.459799 -0.300137
# 765  0.297611  0.002864  0.129846  0.134092  0.242609 -0.637939 -0.594556
# 766 -0.391110  0.073968 -0.217909 -0.596333 -0.320749 -0.111194 -0.171788
# 767 -0.457286 -0.472513  0.025030  0.355247 -0.375020 -0.109400 -0.256432
#
#             7
# 0    0.654334
# 1   -0.103381
# 2   -0.034994
# 3   -0.523940
# 4   -0.003356
# ..        ...
# 763  0.657508
# 764 -0.400167
# 765 -0.239282
# 766  0.541949
# 767 -0.471623
#
# [768 rows x 8 columns]

# %% [markdown]
# ## Principle Component Analysis - PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(2)

# %%
x = df.drop('Outcome', axis=1)

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
x_2 = pca.fit_transform(x)

# %%
x_2
# Out:
# array([[-75.71465491, -35.95078264],
#        [-82.3582676 ,  28.90821322],
#        [-74.63064344, -67.90649647],
#        ...,
#        [ 32.11319827,   3.3766648 ],
#        [-80.21449431, -14.18601977],
#        [-81.30814972,  21.62149606]])

# %%
pd.DataFrame(x_2, columns=['PCA1', 'PCA2'])
# Out:
#           PCA1       PCA2
# 0   -75.714655 -35.950783
# 1   -82.358268  28.908213
# 2   -74.630643 -67.906496
# 3    11.077423  34.898486
# 4    89.743788  -2.746937
# ..         ...        ...
# 763  99.237881  25.080927
# 764 -78.641239  -7.688010
# 765  32.113198   3.376665
# 766 -80.214494 -14.186020
# 767 -81.308150  21.621496
#
# [768 rows x 2 columns]

# %% [markdown]
# We shrinked the original data into two columns. This table is representative of the origianl table, only it was shrinked in columns.

# %%
pca.explained_variance_ratio_
# Out:
# array([0.88854663, 0.06159078])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.9501374183215007

# %% [markdown]
# We did the shrinking with 95% percent of the data intact.
