# %% [markdown]
# # StyleCloud

# %%
import stylecloud as sc

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch.png')

# %%
from IPython.display import Image

# %%
Image('ch.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch1.png', icon_name='fas fa-truck', background_color='cyan')
Image('ch1.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='tr.png', icon_name='fas fa-star-and-crescent')
Image('tr.png')

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='apl.png', icon_name='fas fa-apple-alt')
Image('apl.png')
