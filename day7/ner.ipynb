# %% [markdown]
# # NER - Named Entity Recognition
#
# Recognition of places, people and organizations inside of a piece of text.

# %% [markdown]
# ## Fields that require NLP
#
# 1. NLP - Translation
# 2. POS - Part of Speech
# 3. Sentiment Analysis
# 4. Text Classification
# 5. Text Generation
# 6. Text Summarization
# 7. NER - Named Entity Recognition
# 8. Topic Modelling

# %% [markdown]
# ## Sentiment Analysis

# %%
from textblob import TextBlob as tb

# %%
sentence = '''
Efe loves natural language processing and artificial intelligence.
Turkish Space Agency TUA is the national space agency of Turkey.
'''

# %%
tb(sentence).sentiment.polarity
# Out:
# -0.25

# %% [markdown]
# ## NER

# %%
import spacy
from spacy import displacy
MER = spacy.load('en_core_web_sm')

# %%
text = '''
Efe Acikgoz loves NLP and artificial intelligence. Python is a great programming language. The Turkish Space Agency is
the national space agency of Turkey, headquartered in Ankara. It operates under the Department of Space by the
president of Turkey and administor of TUA is Serdar Huseyin Yildirim.
'''

# %%
text1 = MER(text)

# %%
for word in text1.ents:
    print(word.text, spacy.explain(word.label_))
# Out:
# Acikgoz People, including fictional
# NLP Companies, agencies, institutions, etc.
# The Turkish Space Agency Companies, agencies, institutions, etc.
# Turkey Countries, cities, states
# Ankara Countries, cities, states
# the Department of Space Companies, agencies, institutions, etc.
# Turkey Countries, cities, states
# TUA Companies, agencies, institutions, etc.
# Serdar Huseyin Yildirim People, including fictional

# %%
displacy.render(text1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="38ea67fa133a43f3b122f3ce689bef65-0" class="displacy" width="8975" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Efe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# ...

# %%
displacy.render(text1, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>Efe
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Acikgoz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  loves
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and artificial intelligence. Python is a great programming language.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Turkish Space Agency
# ...
